# %% [markdown]
# <center>
# <h1> TP-Projet d'optimisation numérique </h1>
# <h1> Algorithme de Newton </h1>
# </center>

# %% [markdown]
# ## Implémentation
#
# 1. Coder l’algorithme de Newton dans le fichier `src/newton.jl` en respectant la spécification donnée dans ce même fichier ;
# 2. Exécuter les tests ci-dessous et vérifier qu'ils passent.
#
# Pour les tests, nous avons défini les fonctions suivantes $f_1 \colon \mathbb{R}^3 \to \mathbb{R}$
# et $f_2 \colon \mathbb{R}^2 \to \mathbb{R}$.
#
# $$
#     f_{1}(x_1, x_2, x_3) = 2 (x_1 +x_2 + x_3 -3)^2 + (x_1-x_2)^2 + (x_2 - x_3)^2
# $$
# et
# $$
#     f_{2}(x_1,x_2) = 100(x_2-x_1^2)^2 + (1-x_1)^2.
# $$
#
# **Remarque.** On peut retrouver ces fonctions dans le fichier `test/fonctions_de_tests.jl`.

# %%
include("../src/newton.jl")         # votre algorithme de Newton
include("../test/tester_newton.jl") # la fonction pour tester votre algorithme de Newton

#
afficher = false # si true, alors affiche les résultats des algorithmes

#
tester_newton(newton, afficher); # tester l'algorithme de Newton
# Out:
# Affichage des résultats des algorithmes : false
#
# flag: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:45
#   Expression: flag == 0
#    Evaluated: -1 == 0
# Stacktrace:
#  [1] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:464 [inlined]
#  [2] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:45 [inlined]
#  [3] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [4] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:45 [inlined]
#  [5] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [6] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:33 [inlined]
#  [7] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [8] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# solution: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:55
#   Expression: ≈(x_sol, sol_exacte_fct1, atol = tol_erreur)
#    Evaluated: [1, 0, 0] ≈ [1, 1, 1] (atol=1.4901161193847656e-8)
# Stacktrace:
#  [1] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:464 [inlined]
#  [2] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:55 [inlined]
#  [3] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [4] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:55 [inlined]
#  [5] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [6] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:49 [inlined]
#  [7] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [8] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# itération: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:58
#   Expression: nb_iters == 1
#    Evaluated: 0 == 1
# Stacktrace:
#  [1] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:464 [inlined]
#  [2] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:58 [inlined]
#  [3] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [4] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:58 [inlined]
#  [5] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [6] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:49 [inlined]
#  [7] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [8] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# flag: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:61
#   Expression: flag == 0
#    Evaluated: -1 == 0
# Stacktrace:
#  [1] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:464 [inlined]
#  [2] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:61 [inlined]
#  [3] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [4] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:61 [inlined]
#  [5] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [6] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:49 [inlined]
#  [7] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [8] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# solution: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:71
#   Expression: ≈(x_sol, sol_exacte_fct1, atol = tol_erreur)
#    Evaluated: [10.0, 3.0, -2.2] ≈ [1, 1, 1] (atol=1.4901161193847656e-8)
# Stacktrace:
#  [1] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:464 [inlined]
#  [2] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:71 [inlined]
#  [3] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [4] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:71 [inlined]
#  [5] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [6] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:65 [inlined]
#  [7] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [8] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# itération: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:74
#   Expression: nb_iters == 1
#    Evaluated: 0 == 1
# Stacktrace:
#  [1] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:464 [inlined]
#  [2] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:74 [inlined]
#  [3] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [4] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:74 [inlined]
#  [5] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [6] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:65 [inlined]
#  [7] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [8] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# flag: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:77
#   Expression: flag == 0
#    Evaluated: -1 == 0
# Stacktrace:
#  [1] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:464 [inlined]
#  [2] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:77 [inlined]
#  [3] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [4] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:77 [inlined]
#  [5] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [6] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:65 [inlined]
#  [7] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [8] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# solution: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:87
#   Expression: ≈(x_sol, sol_exacte_fct2, atol = tol_erreur)
#    Evaluated: [-1.2, 1.0] ≈ [1, 1] (atol=1.4901161193847656e-8)
# Stacktrace:
#  [1] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:464 [inlined]
#  [2] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:87 [inlined]
#  [3] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [4] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:87 [inlined]
#  [5] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [6] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:81 [inlined]
#  [7] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [8] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# itération: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:90
#   Expression: nb_iters == 6
#    Evaluated: 0 == 6
# Stacktrace:
#  [1] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:464 [inlined]
#  [2] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:90 [inlined]
#  [3] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [4] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:90 [inlined]
#  [5] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [6] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:81 [inlined]
#  [7] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [8] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# flag: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:93
#   Expression: flag == 0
#    Evaluated: -1 == 0
# Stacktrace:
#  [1] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:464 [inlined]
#  [2] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:93 [inlined]
#  [3] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [4] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:93 [inlined]
#  [5] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [6] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:81 [inlined]
#  [7] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [8] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# solution: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:103
#   Expression: ≈(x_sol, sol_exacte_fct2, atol = tol_erreur)
#    Evaluated: [10, 0] ≈ [1, 1] (atol=1.4901161193847656e-8)
# Stacktrace:
#  [1] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:464 [inlined]
#  [2] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:103 [inlined]
#  [3] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [4] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:103 [inlined]
#  [5] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [6] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:97 [inlined]
#  [7] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [8] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# itération: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:106
#   Expression: nb_iters == 5
#    Evaluated: 0 == 5
# Stacktrace:
#  [1] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:464 [inlined]
#  [2] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:106 [inlined]
#  [3] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [4] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:106 [inlined]
#  [5] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [6] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:97 [inlined]
#  [7] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [8] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# flag: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:109
#   Expression: flag == 0
#    Evaluated: -1 == 0
# Stacktrace:
#  [1] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:464 [inlined]
#  [2] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:109 [inlined]
#  [3] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [4] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:109 [inlined]
#  [5] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [6] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:97 [inlined]
#  [7] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [8] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# solution: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:119
#   Expression: ≈(x_sol, [-4.99999958629818e9, 8.673617379884035e-19], atol = tol_erreur)
#    Evaluated: [0.0, 0.0050000000010000005] ≈ [-4.99999958629818e9, 8.673617379884035e-19] (atol=1.4901161193847656e-8)
# Stacktrace:
#  [1] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:464 [inlined]
#  [2] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:119 [inlined]
#  [3] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [4] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:119 [inlined]
#  [5] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [6] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:113 [inlined]
#  [7] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [8] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# flag: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:122
#   Expression: flag == 3
#    Evaluated: -1 == 3
# Stacktrace:
#  [1] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:464 [inlined]
#  [2] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:122 [inlined]
#  [3] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [4] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:122 [inlined]
#  [5] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [6] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:113 [inlined]
#  [7] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [8] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# itération: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:125
#   Expression: nb_iters == 1
#    Evaluated: 0 == 1
# Stacktrace:
#  [1] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:464 [inlined]
#  [2] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:125 [inlined]
#  [3] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [4] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:125 [inlined]
#  [5] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [6] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:113 [inlined]
#  [7] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [8] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# exception: Test Failed at /home/yelalami/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:128
#   Expression: (_, _, _, _) = newton(fct2, grad_fct2, hess_fct2, pts1.x023, max_iter = max_iter, tol_abs = tol_abs, tol_rel = tol_rel, epsilon = epsilon)
#     Expected: SingularException
#   No exception thrown
# Stacktrace:
#  [1] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:128 [inlined]
#  [2] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [3] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:128 [inlined]
#  [4] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [5] macro expansion
#    @ ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:113 [inlined]
#  [6] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#  [7] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
# Test Summary:             | Pass  Fail  Total  Time
# algorithme de Newton      |    2    17     19  2.6s
#   test f1 : x0 = solution |    2     1      3  1.9s
#     solution              |    1            1  0.3s
#     itération             |    1            1  0.0s
#     flag                  |          1      1  1.6s
#   test f1 : x0 = x011     |          3      3  0.0s
#     solution              |          1      1  0.0s
#     itération             |          1      1  0.0s
#     flag                  |          1      1  0.0s
#   test f1 : x0 = x012     |          3      3  0.4s
#     solution              |          1      1  0.3s
#     itération             |          1      1  0.0s
#     flag                  |          1      1  0.0s
#   test f2 : x0 = x021     |          3      3  0.0s
#     solution              |          1      1  0.0s
#     itération             |          1      1  0.0s
#     flag                  |          1      1  0.0s
#   test f2 : x0 = x022     |          3      3  0.0s
#     solution              |          1      1  0.0s
#     itération             |          1      1  0.0s
#     flag                  |          1      1  0.0s
#   test f2 : x0 = x023     |          4      4  0.2s
#     solution              |          1      1  0.1s
#     flag                  |          1      1  0.0s
#     itération             |          1      1  0.0s
#     exception             |          1      1  0.1s
# Some tests did not pass: 2 passed, 17 failed, 0 errored, 0 broken.
#
# Stacktrace:
#  [1] finish(ts::Test.DefaultTestSet)
#    @ Test /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1092
#  [2] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1368 [inlined]
#  [3] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Bureau/2A/S7/OptimisationNumerique/projet-optinum/test/tester_newton.jl:32
#  [4] top-level scope
#    @ In[1]:8

# %%
include("../src/newton.jl") # votre algorithme de Newton
include("../test/fonctions_de_tests.jl") # pour avoir la fonction d'affichage des résultats

# Fonction f0
# -----------
f0(x)      =  sin(x)
grad_f0(x) =  cos(x) # la gradient de la fonction f0
hess_f0(x) = -sin(x) # la hessienne de la fonction f0
solution   = -pi/2

x0 = solution
x_sol, f_sol, flag, nb_iters = newton(f0, grad_f0, hess_f0, x0)
afficher_resultats("Newton", "f0", x0, x_sol, f_sol, flag, nb_iters, solution)

x0 = -pi/2+0.5
x_sol, f_sol, flag, nb_iters = newton(f0, grad_f0, hess_f0, x0)
afficher_resultats("Newton", "f0", x0, x_sol, f_sol, flag, nb_iters, solution)

x0 = pi/2
x_sol, f_sol, flag, nb_iters = newton(f0, grad_f0, hess_f0, x0)
afficher_resultats("Newton", "f0", x0, x_sol, f_sol, flag, nb_iters, solution)
# Out:
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0:
#   * x0       = -1.5707963267948966
#   * x_sol    = -1.5707963267948966
#   * f(x_sol) = -1.0
#   * nb_iters = 0
#   * flag     = -1
#   * solution = -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0:
#   * x0       = -1.0707963267948966
#   * x_sol    = -1.0707963267948966
#   * f(x_sol) = -0.8775825618903726
#   * nb_iters = 0
#   * flag     = -1
#   * solution = -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0:
#   * x0       = 1.5707963267948966
#   * x_sol    = 1.5707963267948966
#   * f(x_sol) = 1.0
#   * nb_iters = 0
#   * flag     = -1
#   * solution = -1.5707963267948966

# %% [markdown]
# ## Interprétation
#
# 1. Justifier les résultats obtenus pour l'exemple $f_0$ ci-dessus;
# 2. Justifier que l’algorithme implémenté converge en une itération pour $f_{1}$;
# 3. Justifier que l’algorithme puisse ne pas converger pour $f_{2}$ avec certains points initiaux.
#
# **Remarque.** Vous pouvez mettre `affiche=true` dans les tests de l'algorithme de Newton pour
# vous aider.
